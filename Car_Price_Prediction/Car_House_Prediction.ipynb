# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_data = pd.read_csv("C:\\Datasets\\Car_Prediction\\train-data.csv")
test_data =  pd.read_csv("C:\\Datasets\\Car_Prediction\\test-data.csv")

# %%
train_data.head()
# Out:
#    Unnamed: 0                              Name    Location  Year  \
# 0           0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1           1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2           2                      Honda Jazz V     Chennai  2011
# 3           3                 Maruti Ertiga VDI     Chennai  2012
# 4           4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# ...

# %%
train_data.isnull().sum()
# Out:
# Unnamed: 0              0
# Name                    0
# Location                0
# Year                    0
# Kilometers_Driven       0
# Fuel_Type               0
# Transmission            0
# Owner_Type              0
# Mileage                 2
# Engine                 36
# Power                  36
# Seats                  42
# New_Price            5195
# Price                   0
# dtype: int64

# %%
train_data.drop(['Unnamed: 0','New_Price'],axis=1,inplace=True)

# %%
train_data.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                42
# Price                 0
# dtype: int64

# %%
train_data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [raw]
# train_data['Price'] =  train_data['Price']*10000

# %%
def frequency(column,df=train_data):
    print(df[column].value_counts().head(10))

# %%
for column in train_data.columns:
    frequency(column=column)
# Out:
# Mahindra XUV500 W8 2WD        49
# Maruti Swift VDI              45
# Honda City 1.5 S MT           34
# Maruti Swift Dzire VDI        34
# Maruti Swift VDI BSIV         31
# Maruti Ritz VDi               30
# Hyundai i10 Sportz            30
# Toyota Fortuner 3.0 Diesel    29
# Honda Amaze S i-Dtech         27
# Hyundai Grand i10 Sportz      27
# Name: Name, dtype: int64
# Mumbai        790
# Hyderabad     742
# Kochi         651
# Coimbatore    636
# Pune          622
# Delhi         554
# Kolkata       535
# Chennai       494
# Jaipur        413
# Bangalore     358
# Name: Location, dtype: int64
# 2014    797
# 2015    744
# 2016    741
# 2013    649
# 2017    587
# 2012    580
# 2011    466
# 2010    342
# 2018    298
# 2009    198
# Name: Year, dtype: int64
# 60000    82
# 45000    70
# 65000    68
# 50000    61
# 55000    60
# 70000    60
# 30000    54
# 52000    54
# 80000    50
# 75000    50
# Name: Kilometers_Driven, dtype: int64
# Diesel      3205
# Petrol      2746
# ...

# %%
train_data['Total_Years'] = 2023 - train_data['Year']

# %%
train_data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price  Total_Years
# 0   1.75           13
# 1  12.50            8
# ...

# %% [raw]
# train_data.corr()

# %%
sns.heatmap(train_data.corr())
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize=(16,8))
sns.barplot(x='Transmission',y='Kilometers_Driven',data=train_data)
plt.title('How Price differrs with location')
# Out:
# Text(0.5, 1.0, 'How Price differrs with location')

# %%
fig = plt.figure(figsize=(16,8))
sns.barplot(x='Location',y='Price',data=train_data)
plt.title('How Price differrs with Location')
# Out:
# Text(0.5, 1.0, 'How Price differrs with Location')

# %%
sns.countplot(x='Owner_Type',hue='Location',data=train_data)
# Out:
# <AxesSubplot:xlabel='Owner_Type', ylabel='count'>

# %%
sns.countplot(x='Owner_Type',hue='Transmission',data=train_data)
plt.title('Owner Type and Transmission')
# Out:
# Text(0.5, 1.0, 'Owner Type and Transmission')

# %%
fig = plt.figure(figsize=(16,8))
sns.barplot(x='Location',y='Total_Years',data=train_data)
plt.title('Which  Location has the oldest cars?')
# Out:
# Text(0.5, 1.0, 'Which  Location has the oldest cars?')

# %%
fig = plt.figure(figsize=(16,8))
sns.jointplot(x='Total_Years',y='Price',data=train_data)
plt.title('The relationship between age and price ')
# Out:
# Text(0.5, 1.0, 'The relationship between age and price ')

# %%
fig = plt.figure(figsize=(16,8))
sns.boxplot(x='Location',y='Total_Years',data=train_data)
plt.title('Which  Location has the oldest cars?')
# Out:
# Text(0.5, 1.0, 'Which  Location has the oldest cars?')

# %%
fig = plt.figure(figsize=(20,8))
sns.violinplot(x='Location',y='Total_Years',data=train_data)
plt.title('Which  Location has the oldest cars?')
# Out:
# Text(0.5, 1.0, 'Which  Location has the oldest cars?')

# %%
train_data['Seats'].mean()
train_data['Seats'] = train_data['Seats'].fillna('5')

# %%
train_data.isnull().sum()
# Out:
# Name                  0
# Location              0
# Year                  0
# Kilometers_Driven     0
# Fuel_Type             0
# Transmission          0
# Owner_Type            0
# Mileage               2
# Engine               36
# Power                36
# Seats                 0
# Price                 0
# Total_Years           0
# dtype: int64

# %%
plt.figure(figsize=(20,8))
sns.scatterplot(x='Power',y='Price',data=train_data)
# Out:
# <AxesSubplot:xlabel='Power', ylabel='Price'>

# %%
def convert_power(val):
    if not pd.isnull(val):
        return val.split(' ')[0]
    return val

# %%
train_data['Power'] = train_data['Power'].apply(lambda val: convert_power(val))

# %%
def convert_power_data(val):
    if not pd.isnull(val):
        return float(val.split(' ')[0])
    return val

#train_data["Power"] = train_data["Power"].apply(lambda val: convert_power_data(val))

# %%
train_data['Power'].head(20)
# Out:
# 0      58.16
# 1      126.2
# 2       88.7
# 3      88.76
# 4      140.8
# 5       55.2
# 6       63.1
# 7      171.5
# 8      103.6
# 9         74
# 10    103.25
# 11     116.3
# 12        74
# 13     187.7
# 14       115
# 15    175.56
# 16      98.6
# 17        74
# 18      83.8
# 19    167.62
# Name: Power, dtype: object

# %%
train_data.head(10)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 5      Hyundai EON LPG Era Plus Option   Hyderabad  2012              75000
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# 7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016              36000
# 8  Volkswagen Vento Diesel Comfortline        Pune  2013              64430
# 9       Tata Indica Vista Quadrajet LS     Chennai  2012              65932
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine  Power Seats  Price  \
# ...

# %%
train_data['Engine'] = train_data['Engine'].apply(lambda val:convert_power(val))
train_data['Mileage'] = train_data['Mileage'].apply(lambda val:convert_power(val))

# %%
train_data.head(10)
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0               Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                         Honda Jazz V     Chennai  2011              46000
# 3                    Maruti Ertiga VDI     Chennai  2012              87000
# 4      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 5      Hyundai EON LPG Era Plus Option   Hyderabad  2012              75000
# 6               Nissan Micra Diesel XV      Jaipur  2013              86999
# 7    Toyota Innova Crysta 2.8 GX AT 8S      Mumbai  2016              36000
# 8  Volkswagen Vento Diesel Comfortline        Pune  2013              64430
# 9       Tata Indica Vista Quadrajet LS     Chennai  2012              65932
#
#   Fuel_Type Transmission Owner_Type Mileage Engine  Power Seats  Price  \
# ...

# %%
# Dropping Name and  Year
train_data.drop(['Name','Year'],axis=1,inplace=True)

# %%
# Now to determine what our categorigal and continous features will be 
for column in train_data.columns:
    print(f"The total number of elements in {column} are :{len(train_data[column].unique())}")
# Out:
# The total number of elements in Location are :11
# The total number of elements in Kilometers_Driven are :3093
# The total number of elements in Fuel_Type are :5
# The total number of elements in Transmission are :2
# The total number of elements in Owner_Type are :4
# The total number of elements in Mileage are :431
# The total number of elements in Engine are :147
# The total number of elements in Power are :373
# The total number of elements in Seats are :10
# The total number of elements in Price are :1373
# The total number of elements in Total_Years are :22

# %%
import datetime
year = datetime.datetime.now().year
print(year)
# Out:
# 2023

# %%
cat_features = ['Location','Fuel_Type','Transmission','Owner_Type']
out_features = ['Price']

# %%
from sklearn.preprocessing import LabelEncoder

lbl_encoders = {}
lbl_encoders["Fuel_Type"] = LabelEncoder()
lbl_encoders["Fuel_Type"].fit_transform(train_data["Fuel_Type"])
# Out:
# array([0, 1, 4, ..., 1, 4, 1], dtype=int64)

# %%
from sklearn.preprocessing import LabelEncoder
lbl_encoders = {}
for features in cat_features:
    lbl_encoders[features] = LabelEncoder()
    train_data[features] = lbl_encoders[features].fit_transform(train_data[features])

# %%
train_data.head()
# Out:
#    Location  Kilometers_Driven  Fuel_Type  Transmission  Owner_Type Mileage  \
# 0         9              72000          0             1           0    26.6
# 1        10              41000          1             1           0   19.67
# 2         2              46000          4             1           0    18.2
# 3         2              87000          1             1           0   20.77
# 4         3              40670          1             0           2    15.2
#
#   Engine  Power Seats  Price  Total_Years
# 0    998  58.16   5.0   1.75           13
# 1   1582  126.2   5.0  12.50            8
# 2   1199   88.7   5.0   4.50           12
# 3   1248  88.76   7.0   6.00           11
# 4   1968  140.8   5.0  17.74           10
